# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install timm
# !pip install thop
# !pip install Pytorch==1.7.1
# !pip install torchvision==0.8.2
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 431 kB 4.7 MB/s
# ...
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ERROR: Could not find a version that satisfies the requirement Pytorch==1.7.1 (from versions: 0.1.2, 1.0.2)
# ERROR: No matching distribution found for Pytorch==1.7.1
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 12.8 MB 4.7 MB/s
# ...
#      |████████████████████████████████| 776.8 MB 18 kB/s
# ...
#   Attempting uninstall: torch
#     Found existing installation: torch 1.11.0+cu113
#     Uninstalling torch-1.11.0+cu113:
#       Successfully uninstalled torch-1.11.0+cu113
#   Attempting uninstall: torchvision
# ...

# %%
# !cp -r /content/drive/MyDrive/Polyp-PVT ./
# !rm -r Polyp-PVT/model_pth/*
# !cp /content/drive/MyDrive/final_vessels/230PolypPVT-best.pth Polyp-PVT/model_pth/PolypPVT.pth

# %%
# !chmod +x Polyp-PVT/test.sh && chmod +x test.py && ./test.py /content/drive/MyDrive/unet_training/val/images/ vessels --patch-dimensions 250 250 --model-path ./Polyp-PVT
# Out:
# Running the prediction
# Vessels Finish!

# %%
# !zip -r validation2.zip vessels/
# Out:
#   adding: vessels/ (stored 0%)
#   adding: vessels/1.png (deflated 14%)
#   adding: vessels/3.png (deflated 12%)
#   adding: vessels/4.png (deflated 13%)
#   adding: vessels/8.png (deflated 12%)
#   adding: vessels/6.png (deflated 12%)
#   adding: vessels/2.png (deflated 14%)
#   adding: vessels/5.png (deflated 13%)
#   adding: vessels/7.png (deflated 14%)
